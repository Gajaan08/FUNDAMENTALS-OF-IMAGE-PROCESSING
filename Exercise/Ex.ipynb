# %%
for i in range(1,6):
    print(i,': ',i*i)
# Out:
# 1 :  1
# 2 :  4
# 3 :  9
# 4 :  16
# 5 :  25

# %%
import sympy
for i in range(1,6):
    if not(sympy.isprime(i)):
        print(i,': ',i*i)
# Out:
# 1 :  1
# 4 :  16

# %%
import numpy as np
M1=([1,2],[3,4],[5,6])
M2=([7,8,9,1],[1,2,3,4])
R1=np.dot(M1,M2)
R2=np.matmul(M1,M2)
print("R1:",R1)
print("R2:",R2)
# Out:
# R1: [[ 9 12 15  9]
#  [25 32 39 19]
#  [41 52 63 29]]
# R2: [[ 9 12 15  9]
#  [25 32 39 19]
#  [41 52 63 29]]

# %%
import numpy as np
M1=([1,2],[3,4],[5,6])
M2=([3,2],[5,4],[3,1])
R=np.multiply(M1,M2)
print("R:",R)
# Out:
# R: [[ 3  4]
#  [15 16]
#  [15  6]]

# %%
import numpy as np
A=np.random.randint(0,10,size=(5,7))
A
# Out:
# array([[5, 5, 3, 1, 4, 3, 2],
#        [2, 4, 8, 8, 5, 1, 2],
#        [4, 8, 7, 4, 3, 3, 1],
#        [8, 4, 1, 5, 4, 5, 0],
#        [8, 0, 1, 3, 5, 9, 4]])

# %%
A[1:4,0:3]
# Out:
# array([[2, 4, 8],
#        [4, 8, 7],
#        [8, 4, 1]])

# %%
np.size(A[1:4,0:3])
# Out:
# 9

# %%
import numpy as np
m,c=2,-4
N=10
x=np.linspace(0,N-1,N).reshape(N,1)
sigma=10
y=m*x+c+np.random.normal(0,sigma,(N,1))
X=np.append(np.ones((N,1)),x,axis=1)
from numpy import linalg
W=np.linalg.inv(X.T@X)@X.T@y
W
# Out:
# array([[-5.99738705],
#        [ 3.09455401]])

# %%
# Gaussian smoothing to filter the noise in the image
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread('gal_gaussian.png')
im=cv.cvtColor(im,cv.COLOR_BGR2RGB)
blur=cv.blur(im,(5,5),0)
Gblur=cv.GaussianBlur(im,(5,5),0)
plt.subplots(figsize=(12, 8))
plt.subplot(131),plt.imshow(im),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(blur),plt.title("Average Smoothing Image"),plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(Gblur),plt.title("Gaussian blurring Smoothing Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Averaging
# This is done by convolving an image with a normalized box filter. It simply takes the average of all the pixels under the kernel area and replaces the central element. This is done by the function cv.blur() or cv.boxFilter().
#
# Gaussian Blurring
# In this method, instead of a box filter, a Gaussian kernel is used. It is done with the function, cv.GaussianBlur(). We should specify the width and height of the kernel which should be positive and odd. We also should specify the standard deviation in the X and Y directions, sigmaX and sigmaY respectively. If only sigmaX is specified, sigmaY is taken as the same as sigmaX. If both are given as zeros, they are calculated from the kernel size. Gaussian blurring is highly effective in removing Gaussian noise from an image.

# %%
# Median filtering to filter the salt and pepper noise
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread('gal_sandp.png')
im=cv.cvtColor(im,cv.COLOR_BGR2RGB)
Mblur = cv.medianBlur(im, 5)
plt.subplots(figsize=(8, 8))
plt.subplot(121),plt.imshow(im),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(Mblur),plt.title("Median Filter Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Median Blurring
# Here, the function cv.medianBlur() takes the median of all the pixels under the kernel area and the central element is replaced with this median value. This is highly effective against salt-and-pepper noise in an image. Interestingly, in the above filters, the central element is a newly calculated value which may be a pixel value in the image or a new value. But in median blurring, the central element is always replaced by some pixel value in the image. It reduces the noise effectively. Its kernel size should be a positive odd integer

# %%
# 40×60 grayscale image and change the color of the top-right quarter to 125
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
im=np.zeros((40,60),dtype=np.uint8)
im[0:21,30:61]=125
plt.imshow(im,cmap='gray',vmin=0,vmax=255),plt.title("Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %%
# 40×60 color image and change the color of the bottom-left quarter to “Barbie
#Pink"
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
im=np.zeros((40,60,3),dtype=np.uint8)
im[20:41 , 0:31] = [218,24,132]
plt.imshow(im,cmap='gray',vmin=0,vmax=255),plt.title("Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread('tom_dark.jpg')
im=cv.cvtColor(im,cv.COLOR_BGR2RGB)
a=2
b=20
br_im=cv.convertScaleAbs(im,alpha=a,beta=b)
plt.subplots(figsize=(8, 8))
plt.subplot(121),plt.imshow(im),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(br_im),plt.title("Bright Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Increase brightness of an image(grayscale image)
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread('tom_dark.jpg',cv.IMREAD_GRAYSCALE)
imc=cv.add(im,120)
plt.subplots(figsize=(8, 8))
plt.subplot(121),plt.imshow(im,cmap='gray',vmin=0,vmax=255),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(imc,cmap='gray',vmin=0,vmax=255),plt.title("Bright Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Gamma Correction
import cv2 as cv
import matplotlib.pyplot as plt
img_orig=cv.imread('spider.png')
img_orig=cv.cvtColor(img_orig,cv.COLOR_BGR2RGB)
plt.subplots(figsize=(18, 8))
plot=[152,153,154,155]
gamma=[0.2,0.8,1.2,2]
plt.subplot(151),plt.imshow(img_orig),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
for g in range(4) :
    table=np.array([(i/255.0)**(gamma[g])*255.0 for i in np.arange(0,256)]).astype('uint8')
    img_gamma = cv.LUT(img_orig,table)
    plt.subplot(plot[g]),plt.imshow(img_gamma),plt.title("Gamma Corrected ("+str(gamma[g])+") Image"),plt.xticks([]), plt.yticks([]) 
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
t1 = np.linspace(0,100,50).astype('uint8')
t2 = np.linspace(101,255,150).astype('uint8')
t3 = np.linspace(255,255,56).astype('uint8')
t = np.concatenate((t1,t2,t3),axis=0).astype('uint8')
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input,$f(\mathbf{x})$')
ax.set_ylabel('Output,$\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0.255)
ax.set_ylim(0,255)
plt.show()

# %%
img = cv.imread('spider.png',cv.IMREAD_COLOR)
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.show()
imgtrans = cv.LUT(img,t)
plt.imshow(imgtrans),plt.title("Transformed Image"),plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.imread('shells.tif',cv.IMREAD_COLOR)
plt.subplots(figsize=(8, 4))
plt.subplot(121),plt.imshow(img),plt.title("Original Image"),plt.xticks([]), plt.yticks([])
plt.subplot(122)
color = ('b','g','r')
for i,c in enumerate(color):
    hist = cv.calcHist([img],[i],None,[256],[0,256])
    plt.plot(hist,color=c)
    plt.xlim([0,256])
    plt.ylim([0,20000])
plt.title("Histogram of original Image")
plt.show()

# %%
img = cv.imread('shells.tif',cv.IMREAD_GRAYSCALE)#Gray Scale equalization
equ = cv.equalizeHist(img)
equ = cv.cvtColor(equ, cv.COLOR_BGR2RGB)
plt.subplots(figsize=(8, 4))
plt.subplot(121),plt.imshow(equ,cmap='gray'),plt.title("Equalized Image"),plt.xticks([]), plt.yticks([])
plt.subplot(122)
histeq = cv.calcHist([equ],[i],None,[256],[0,256])
plt.plot(histeq)
plt.xlim([0,256])
plt.ylim([0,20000])
plt.title("Histogram of equalized Image")
plt.show()
